# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize

# Read the requirements and food items data
requirements = pd.read_csv('requisitos.csv').set_index('Sexo')
food_items = pd.read_csv('tbalimentos.csv').set_index('NomeAlimento')

# Define a function to calculate the total nutrients for a given selection of food items
total_nutrients = calculate_total_nutrients(list(selection), sex, weight)  # Ensure selection is a list
# Out:
# The selection of food items that best meets the requirements for a Male with 70kg is:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\felip\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# ...
